# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## The mathematical building blocks of neural networks

# %% [markdown]
# ### A first look at a neural network

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
import keras
from keras import layers

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9260 - loss: 0.2644
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9688 - loss: 0.1074
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9798 - loss: 0.0694
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9858 - loss: 0.0491
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9895 - loss: 0.0359

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# array([4.3863130e-07, 9.6811599e-09, 1.3784376e-05, 3.2638328e-04,
#        4.0164469e-10, 8.6454003e-07, 6.5209373e-11, 9.9963284e-01,
#        1.2925898e-06, 2.4297631e-05], dtype=float32)

# %%
predictions[0].argmax()
# Out:
# np.int64(7)

# %%
predictions[0][7]
# Out:
# np.float32(0.99963284)

# %%
test_labels[0]
# Out:
# np.uint8(7)

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9791 - loss: 0.0678
# test_acc: 0.9790999889373779

# %% [markdown]
# ### Data representations for neural networks

# %% [markdown]
# #### Scalars (rank-0 tensors)

# %%
import numpy as np
x = np.array(12)
x
# Out:
# array(12)

# %%
x.ndim
# Out:
# 0

# %% [markdown]
# #### Vectors (rank-1 tensors)

# %%
x = np.array([12, 3, 6, 14, 7])
x
# Out:
# array([12,  3,  6, 14,  7])

# %%
x.ndim
# Out:
# 1

# %% [markdown]
# #### Matrices (rank-2 tensors)

# %%
x = np.array([[5, 78, 2, 34, 0],
              [6, 79, 3, 35, 1],
              [7, 80, 4, 36, 2]])
x.ndim
# Out:
# 2

# %% [markdown]
# #### Rank-3 tensors and higher-rank tensors

# %%
x = np.array([[[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]]])
x.ndim
# Out:
# 3

# %% [markdown]
# #### Key attributes

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.ndim
# Out:
# 3

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images.dtype
# Out:
# dtype('uint8')

# %%
import matplotlib.pyplot as plt

digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
train_labels[4]
# Out:
# np.uint8(9)

# %% [markdown]
# #### Manipulating tensors in NumPy

# %%
my_slice = train_images[10:100]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100, :, :]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100, 0:28, 0:28]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[:, 14:, 14:]

# %%
my_slice = train_images[:, 7:-7, 7:-7]

# %% [markdown]
# #### The notion of data batches

# %%
batch = train_images[:128]

# %%
batch = train_images[128:256]

# %%
n = 3
batch = train_images[128 * n : 128 * (n + 1)]

# %% [markdown]
# #### Real-world examples of data tensors

# %% [markdown]
# ##### Vector data

# %% [markdown]
# ##### Timeseries data or sequence data

# %% [markdown]
# ##### Image data

# %% [markdown]
# ##### Video data

# %% [markdown]
# ### The gears of neural networks: Tensor operations

# %% [markdown]
# #### Element-wise operations

# %%
def naive_relu(x):
    assert len(x.shape) == 2
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] = max(x[i, j], 0)
    return x

# %%
def naive_add(x, y):
    assert len(x.shape) == 2
    assert x.shape == y.shape
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[i, j]
    return x

# %%
import time

x = np.random.random((20, 100))
y = np.random.random((20, 100))

t0 = time.time()
for _ in range(1000):
    z = x + y
    z = np.maximum(z, 0.0)
print("Took: {0:.2f} s".format(time.time() - t0))
# Out:
# Took: 0.01 s

# %%
t0 = time.time()
for _ in range(1000):
    z = naive_add(x, y)
    z = naive_relu(z)
print("Took: {0:.2f} s".format(time.time() - t0))
# Out:
# Took: 1.59 s

# %% [markdown]
# #### Broadcasting

# %%
import numpy as np

X = np.random.random((32, 10))
y = np.random.random((10,))

# %%
y = np.expand_dims(y, axis=0)

# %%
Y = np.tile(y, (32, 1))

# %%
def naive_add_matrix_and_vector(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[j]
    return x

# %%
import numpy as np

x = np.random.random((64, 3, 32, 10))
y = np.random.random((32, 10))
z = np.maximum(x, y)

# %% [markdown]
# #### Tensor product

# %%
x = np.random.random((32,))
y = np.random.random((32,))

z = np.matmul(x, y)
z = x @ y

# %%
def naive_vector_product(x, y):
    assert len(x.shape) == 1
    assert len(y.shape) == 1
    assert x.shape[0] == y.shape[0]
    z = 0.0
    for i in range(x.shape[0]):
        z += x[i] * y[i]
    return z

# %%
def naive_matrix_vector_product(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            z[i] += x[i, j] * y[j]
    return z

# %%
def naive_matrix_vector_product(x, y):
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        z[i] = naive_vector_product(x[i, :], y)
    return z

# %%
def naive_matrix_product(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 2
    assert x.shape[1] == y.shape[0]
    z = np.zeros((x.shape[0], y.shape[1]))
    for i in range(x.shape[0]):
        for j in range(y.shape[1]):
            row_x = x[i, :]
            column_y = y[:, j]
            z[i, j] = naive_vector_product(row_x, column_y)
    return z

# %% [markdown]
# #### Tensor reshaping

# %%
train_images = train_images.reshape((60000, 28 * 28))

# %%
x = np.array([[0., 1.],
              [2., 3.],
              [4., 5.]])
x.shape
# Out:
# (3, 2)

# %%
x = x.reshape((6, 1))
x
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [3.],
#        [4.],
#        [5.]])

# %%
x = x.reshape((2, 3))
x
# Out:
# array([[0., 1., 2.],
#        [3., 4., 5.]])

# %%
x = np.zeros((300, 20))
x = np.transpose(x)
x.shape
# Out:
# (20, 300)

# %% [markdown]
# #### Geometric interpretation of tensor operations

# %% [markdown]
# #### A geometric interpretation of deep learning

# %% [markdown]
# ### The engine of neural networks: Gradient-based optimization

# %% [markdown]
# #### What's a derivative?

# %% [markdown]
# #### Derivative of a tensor operation: The gradient

# %% [markdown]
# #### Stochastic gradient descent

# %% [markdown]
# #### Chaining derivatives: The Backpropagation algorithm

# %% [markdown]
# ##### The chain rule

# %% [markdown]
# ##### Automatic differentiation with computation graphs

# %% [markdown]
# ### Looking back at our first example

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
model.fit(
    train_images,
    train_labels,
    epochs=5,
    batch_size=128,
)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9252 - loss: 0.2658
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9679 - loss: 0.1092
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9783 - loss: 0.0714
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9846 - loss: 0.0513
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9893 - loss: 0.0374

# %% [markdown]
# #### Reimplementing our first example from scratch

# %% [markdown]
# ##### A simple Dense class

# %%
import keras
from keras import ops

class NaiveDense:
    def __init__(self, input_size, output_size, activation=None):
        self.activation = activation
        self.W = keras.Variable(
            shape=(input_size, output_size), initializer="uniform"
        )
        self.b = keras.Variable(shape=(output_size,), initializer="zeros")

    def __call__(self, inputs):
        x = ops.matmul(inputs, self.W)
        x = x + self.b
        if self.activation is not None:
            x = self.activation(x)
        return x

    @property
    def weights(self):
        return [self.W, self.b]

# %% [markdown]
# ##### A simple Sequential class

# %%
class NaiveSequential:
    def __init__(self, layers):
        self.layers = layers

    def __call__(self, inputs):
        x = inputs
        for layer in self.layers:
            x = layer(x)
        return x

    @property
    def weights(self):
        weights = []
        for layer in self.layers:
            weights += layer.weights
        return weights

# %%
model = NaiveSequential(
    [
        NaiveDense(input_size=28 * 28, output_size=512, activation=ops.relu),
        NaiveDense(input_size=512, output_size=10, activation=ops.softmax),
    ]
)
assert len(model.weights) == 4

# %% [markdown]
# ##### A batch generator

# %%
import math

class BatchGenerator:
    def __init__(self, images, labels, batch_size=128):
        assert len(images) == len(labels)
        self.index = 0
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.num_batches = math.ceil(len(images) / batch_size)

    def next(self):
        images = self.images[self.index : self.index + self.batch_size]
        labels = self.labels[self.index : self.index + self.batch_size]
        self.index += self.batch_size
        return images, labels

# %% [markdown]
# #### Running one training step

# %% [markdown]
# ##### The weight update step

# %%
learning_rate = 1e-3

def update_weights(gradients, weights):
    for g, w in zip(gradients, weights):
        w.assign(w - g * learning_rate)

# %%
from keras import optimizers

optimizer = optimizers.SGD(learning_rate=1e-3)

def update_weights(gradients, weights):
    optimizer.apply_gradients(zip(gradients, weights))

# %% [markdown]
# ##### Gradient computation

# %%
# %%backend tensorflow
# import tensorflow as tf
#
# x = tf.zeros(shape=())
# with tf.GradientTape() as tape:
#     y = 2 * x + 3
# grad_of_y_wrt_x = tape.gradient(y, x)

# %%
# %%backend tensorflow
# def one_training_step(model, images_batch, labels_batch):
#     with tf.GradientTape() as tape:
#         predictions = model(images_batch)
#         loss = ops.sparse_categorical_crossentropy(labels_batch, predictions)
#         average_loss = ops.mean(loss)
#     gradients = tape.gradient(average_loss, model.weights)
#     update_weights(gradients, model.weights)
#     return average_loss

# %% [markdown]
# #### The full training loop

# %%
# %%backend tensorflow
# def fit(model, images, labels, epochs, batch_size=128):
#     for epoch_counter in range(epochs):
#         print(f"Epoch {epoch_counter}")
#         batch_generator = BatchGenerator(images, labels)
#         for batch_counter in range(batch_generator.num_batches):
#             images_batch, labels_batch = batch_generator.next()
#             loss = one_training_step(model, images_batch, labels_batch)
#             if batch_counter % 100 == 0:
#                 print(f"loss at batch {batch_counter}: {loss:.2f}")

# %%
# %%backend tensorflow
# from keras.datasets import mnist
#
# (train_images, train_labels), (test_images, test_labels) = mnist.load_data()
#
# train_images = train_images.reshape((60000, 28 * 28))
# train_images = train_images.astype("float32") / 255
# test_images = test_images.reshape((10000, 28 * 28))
# test_images = test_images.astype("float32") / 255
#
# fit(model, train_images, train_labels, epochs=10, batch_size=128)
# Out:
# Epoch 0
# loss at batch 0: 2.29
# loss at batch 100: 2.25
# loss at batch 200: 2.21
# loss at batch 300: 2.16
# loss at batch 400: 2.11
# Epoch 1
# loss at batch 0: 2.09
# loss at batch 100: 2.08
# loss at batch 200: 2.02
# loss at batch 300: 1.98
# loss at batch 400: 1.93
# Epoch 2
# loss at batch 0: 1.90
# loss at batch 100: 1.91
# loss at batch 200: 1.83
# loss at batch 300: 1.80
# loss at batch 400: 1.75
# Epoch 3
# loss at batch 0: 1.70
# loss at batch 100: 1.73
# loss at batch 200: 1.63
# loss at batch 300: 1.60
# loss at batch 400: 1.56
# Epoch 4
# loss at batch 0: 1.50
# loss at batch 100: 1.55
# loss at batch 200: 1.42
# loss at batch 300: 1.41
# loss at batch 400: 1.39
# Epoch 5
# loss at batch 0: 1.32
# loss at batch 100: 1.37
# loss at batch 200: 1.24
# loss at batch 300: 1.24
# loss at batch 400: 1.24
# Epoch 6
# loss at batch 0: 1.16
# loss at batch 100: 1.21
# loss at batch 200: 1.08
# loss at batch 300: 1.10
# loss at batch 400: 1.12
# Epoch 7
# loss at batch 0: 1.02
# loss at batch 100: 1.08
# loss at batch 200: 0.96
# loss at batch 300: 0.99
# loss at batch 400: 1.02
# Epoch 8
# loss at batch 0: 0.92
# loss at batch 100: 0.98
# loss at batch 200: 0.85
# loss at batch 300: 0.89
# loss at batch 400: 0.94
# Epoch 9
# loss at batch 0: 0.84
# loss at batch 100: 0.89
# loss at batch 200: 0.77
# loss at batch 300: 0.82
# loss at batch 400: 0.87

# %% [markdown]
# #### Evaluating the model

# %%
# %%backend tensorflow
# predictions = model(test_images)
# predicted_labels = ops.argmax(predictions, axis=1)
# matches = predicted_labels == test_labels
# f"accuracy: {ops.mean(matches):.2f}"
# Out:
# 'accuracy: 0.84'

# %% [markdown]
# check weights from defined models

# %%
print(f"Total number of weight tensors: {len(model.weights)}")

for i, layer in enumerate(model.layers, start=1):
    print(f"\nLayer {i}")

    for name, weight in zip(["W", "b"], layer.weights):
        values = ops.convert_to_numpy(weight)

        print(f"{name} shape: {values.shape}")
        print(f"{name} values (first 5): {values.flatten()[:5]}")
# Out:
# Total number of weight tensors: 4
#
# Layer 1
# W shape: (784, 512)
# W values (first 5): [ 0.00640095 -0.01177918  0.01657713  0.03124018  0.02567608]
# b shape: (512,)
# b values (first 5): [-0.00121134  0.00333441  0.00583384  0.00764422  0.00579475]
#
# Layer 2
# W shape: (512, 10)
# W values (first 5): [ 0.0378581   0.00419316  0.03304255  0.02680815 -0.00013615]
# b shape: (10,)
# b values (first 5): [-0.03520432  0.08133734 -0.0188281  -0.0182146   0.01879742]

# %% [markdown]
# try running naive version of model and check weights.

# %%
sample_images = test_images[:5]
sample_outputs = model(sample_images)

print("Input shape :", sample_images.shape)
print("Output shape:", sample_outputs.shape)
print("\nModel outputs:")
print(sample_outputs)

# Check weights
print("\nNumber of weight tensors:", len(model.weights))

for i, layer in enumerate(model.layers, start=1):
    print(f"\nLayer {i}")
    print("W shape:", layer.W.shape)
    print("b shape:", layer.b.shape)

    print("W sample:", ops.convert_to_numpy(layer.W).flatten()[:5])
    print("b sample:", ops.convert_to_numpy(layer.b).flatten()[:5])
# Out:
# Input shape : (5, 784)
# Output shape: (5, 10)
#
# Model outputs:
# tf.Tensor(
# [[1.4646575e-02 5.1952018e-03 1.0866678e-02 2.2375321e-02 3.5781577e-02
#   1.8437535e-02 5.8462969e-03 7.6125956e-01 2.4642788e-02 1.0094847e-01]
#  [6.4430341e-02 6.1821379e-02 3.0588546e-01 1.8468125e-01 7.0674117e-03
#   1.0067730e-01 1.7375430e-01 4.3367799e-03 9.1658093e-02 5.6875986e-03]
#  [1.2237104e-02 6.6981351e-01 6.3734569e-02 5.2104205e-02 1.5078130e-02
#   2.8197641e-02 3.0656150e-02 3.3729423e-02 6.9397636e-02 2.5051584e-02]
#  [8.4346080e-01 3.3471803e-04 1.1916685e-02 7.6637487e-03 6.8277302e-03
#   3.5593517e-02 6.2641077e-02 1.5012343e-02 8.0867391e-03 8.4626954e-03]
#  [3.3847034e-02 4.4688075e-03 6.9085024e-02 1.8754834e-02 4.7122812e-01
#   3.6926389e-02 6.2633678e-02 1.0271977e-01 3.7272878e-02 1.6306339e-01]], shape=(5, 10), dtype=float32)
#
# Number of weight tensors: 4
#
# Layer 1
# W shape: (784, 512)
# b shape: (512,)
# W sample: [ 0.00640095 -0.01177918  0.01657713  0.03124018  0.02567608]
# b sample: [-0.00121134  0.00333441  0.00583384  0.00764422  0.00579475]
#
# Layer 2
# W shape: (512, 10)
# b shape: (10,)
# W sample: [ 0.0378581   0.00419316  0.03304255  0.02680815 -0.00013615]
# b sample: [-0.03520432  0.08133734 -0.0188281  -0.0182146   0.01879742]
